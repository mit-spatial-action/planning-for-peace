# %%
from spacy import load
import pandas as pd
from enum import Enum

nlp = load("en_core_web_trf")

# %%
import re

def process_text(text:str) -> str:
    text = re.sub(r"^(the|an) ", "", text, flags=re.IGNORECASE)
    text = re.sub(r"^-|-$", "", text, flags=re.IGNORECASE)
    text = re.sub(r"[’']s$", "", text, flags=re.IGNORECASE)
    text = re.sub(r"\.", "", text, flags=re.IGNORECASE)
    return text

def filter_entities(doc, entity_type: str) -> list[str]:
    a = [process_text(ent.text) for ent in doc.ents if ent.label_ in entity_type]
    return list(set(a))

def resolve_entities(text: str, prefix: str) -> dict:
    doc = nlp(text)
    return {
        f"{prefix}_geo": filter_entities(doc, ["GPE", "LOC"]),
        f"{prefix}_org": filter_entities(doc, "ORG"),
        f"{prefix}_ppl": filter_entities(doc, "PERSON"),
    }

def resolve_entities_multi(df: pd.DataFrame, cols: list[str]) -> pd.DataFrame:
    for col in cols:
        df = pd.concat(
            [
                df, 
                test.get(col).apply(resolve_entities, prefix=col).apply(pd.Series)
            ], 
            axis=1
            )
    return df
    

test = pd.read_csv("output.csv", keep_default_na=False)

results = resolve_entities_multi(test, cols=["title", "abstract"])

# %%
print(results)
# Out:
#                               oa_id  \
# 0  https://openalex.org/W1520259670
# 1  https://openalex.org/W3117619809
# 2  https://openalex.org/W1487766560
# 3  https://openalex.org/W4213049131
# 4   https://openalex.org/W578223960
# 5  https://openalex.org/W2483500851
# 6  https://openalex.org/W2295723959
# 7  https://openalex.org/W1989753893
# 8  https://openalex.org/W3175380181
# 9  https://openalex.org/W2941382029
#
#                                                  doi  \
# 0        https://doi.org/10.1093/0199291926.001.0001
# 1
# 2             https://doi.org/10.5860/choice.52-0562
# 3  https://doi.org/10.1093/oso/9780197508893.001....
# 4
# 5        https://doi.org/10.1093/0199291926.003.0013
# 6      https://doi.org/10.1080/01419870.2016.1155722
# 7      https://doi.org/10.1016/s1090-9524(01)00023-7
# 8          https://doi.org/10.1136/bmjgh-2021-006504
# 9          https://doi.org/10.1017/s0031819119000019
#
#                                                title  \
# 0                        The Handbook of Reparations
# 1  Looking to the Bottom: Critical Legal Studies ...
# 2  Racist America: roots, current realities, and ...
# 3                          Reconsidering Reparations
# 4  When Sorry Isn't Enough: The Controversy Over ...
# 5                            Justice and Reparations
# 6  The social life of DNA: race, reparations, and...
# 7  Racist America: roots, current realities, and ...
# 8  Global vaccine equity demands reparative justi...
# 9            Reparative Justice for Climate Refugees
#
#                                              authors  \
# 0                                    Pablo de Greiff
# 1                                       Mari Matsuda
# 2                                      Joe R. Feagin
# 3                                  Olúfẹ́mi O. Táíwò
# 4                                      Roy L. Brooks
# 5                                    Pablo de Greiff
# 6                                       Ros Williams
# 7                                    Noel A Cazenave
# 8  Sophie Harman,Parsa Erfani,Tinashe Goronga,Jas...
# 9                                     Rebecca Buxton
#
#                       publication  year language     item_type     fwci  \
# 0  Oxford University Press eBooks  2006       en          book     9.14
# 1                                  1987       en       article   11.442
# 2           Choice Reviews Online  2014       en       article  143.215
# 3  Oxford University Press eBooks  2022       en          book  116.511
# 4                                  1999       en          book    5.392
# 5  Oxford University Press eBooks  2006       en  book-chapter   13.857
# 6       Ethnic and Racial Studies  2016       en       article   18.557
# 7                Race and Society  2000       en       article    5.439
# 8               BMJ Global Health  2021       en     editorial
# 9                      Philosophy  2019       en       article    2.042
#
#    cited_by                                           keywords  \
# 0       340
# 1       550
# 2       670  Oppression,Framing (construction),White (mutat...
# 3       333
# 4       378  Amnesty,Redress,Injustice,Comfort women,Immora...
# 5       172                                            CLARITY
# 6       323
# 7       285                                             Python
# 8        96            Equity,Queen (butterfly),Social Justice
# 9        58                         Obligation,Climate Justice
#
#                                               topics  \
# 0  Middle East and Rwanda Conflicts,Cambodian His...
# 1  Law in Society and Culture,Legal Education and...
# 2                Race, History, and American Society
# 3  Political Conflict and Governance,Anthropologi...
# 4  Global Peace and Security Dynamics,Internation...
# 5  International Law and Human Rights,Global Peac...
# 6                        Race, Genetics, and Society
# 7  Microbial Fuel Cells and Bioremediation,Metabo...
# 8  Viral Infections and Outbreaks Research,Vaccin...
# 9  Climate Change and Geoengineering,Climate Chan...
#
#                                             concepts  \
# 0                          Computer science,Business
# 1                              Law,Political science
# 2  Racism,Oppression,Framing (construction),Gende...
# 3                       Political science,Philosophy
# 4  Amnesty,Redress,Injustice,Human rights,Politic...
# 5  Economic Justice,Solidarity,Harm,Natural (arch...
# 6  Race (biology),Genome,Sociology,DNA,Genealogy,...
# 7  Microbial fuel cell,Wastewater,Python (program...
# 8  Equity (law),Morse code,Queen (butterfly),Soci...
# 9  Refugee,Obligation,Harm,Economic Justice,Arrow...
#
#                                             abstract  title_geo title_org  \
# 0  Its contributions to the UN's Rule of Law Tool...         []        []
# 1                                                            []        []
# 2  1. Systematic Racism 2. Slavery Unwilling to D...  [America]        []
# 3  Abstract Christopher Columbus’s voyage changed...         []        []
# 4   much compensation ought to be paid to a woman...         []        []
# 5  This paper seeks to articulate a conception of...         []        []
# 6  The proof of one's self – of one's origins or ...         []        []
# 7                                                     [America]        []
# 8  Vaccine apartheid has its roots in colonialism...         []        []
# 9  Abstract This paper sketches an account of rep...         []        []
#
#   title_ppl                                abstract_geo  \
# 0        []                                   [America]
# 1        []                                          []
# 2        []                                          []
# 3        []                                          []
# 4        []  [Japan, Canada, Germany, South Africa, US]
# 5        []                                          []
# 6        []                                          []
# 7        []                                          []
# 8        []                                          []
# 9        []                                          []
#
#                                         abstract_org  \
# 0                        [Justice as Prevention, UN]
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4        [UN Commission on Human Rights, Commission]
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8  [Harvard, LSE, Queen Mary University of London...
# 9                                                 []
#
#                                         abstract_ppl
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                             [Christopher Columbus]
# 4                                     [Karen Parker]
# 5                                                 []
# 6                                           [Nelson]
# 7                                                 []
# 8  [Michelle Morse, Parsa Erfani, Sophie Harman, ...
# 9                                                 []
